# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("covid_19_india .csv")

# %%
data.drop('Sno',axis=1,inplace=True)
data.drop('ConfirmedForeignNational',axis=1,inplace=True)
data
# Out:
#           Date     Time              State/UnionTerritory  \
# 0     30/01/20  6:00 PM                            Kerala
# 1     31/01/20  6:00 PM                            Kerala
# 2     01/02/20  6:00 PM                            Kerala
# 3     02/02/20  6:00 PM                            Kerala
# 4     03/02/20  6:00 PM                            Kerala
# ...        ...      ...                               ...
# 3670  02/07/20  8:00 AM                           Tripura
# 3671  02/07/20  8:00 AM                       Uttarakhand
# 3672  02/07/20  8:00 AM                     Uttar Pradesh
# 3673  02/07/20  8:00 AM                       West Bengal
# 3674  02/07/20  8:00 AM  Cases being reassigned to states
#
#      ConfirmedIndianNational  Cured  Deaths  Confirmed
# 0                          1      0       0          1
# 1                          1      0       0          1
# 2                          2      0       0          2
# 3                          3      0       0          3
# 4                          3      0       0          3
# ...                      ...    ...     ...        ...
# 3670                       -   1093       1       1396
# 3671                       -   2317      41       2947
# 3672                       -  16629     718      24056
# 3673                       -  12528     683      19170
# 3674                       -      0       0       6832
#
# [3675 rows x 7 columns]

# %%
state = pd.DataFrame(data[data["State/UnionTerritory"]=="Punjab"])

state
# Out:
#           Date     Time State/UnionTerritory ConfirmedIndianNational  Cured  \
# 77    09/03/20  6:00 PM               Punjab                       1      0
# 92    10/03/20  6:00 PM               Punjab                       1      0
# 107   11/03/20  6:00 PM               Punjab                       1      0
# 118   12/03/20  6:00 PM               Punjab                       1      0
# 131   13/03/20  6:00 PM               Punjab                       1      0
# ...        ...      ...                  ...                     ...    ...
# 3521  28/06/20  8:00 AM               Punjab                       -   3320
# 3557  29/06/20  8:00 AM               Punjab                       -   3526
# 3593  30/06/20  8:00 AM               Punjab                       -   3764
# 3629  01/07/20  8:00 AM               Punjab                       -   3867
# 3665  02/07/20  8:00 AM               Punjab                       -   3867
#
#       Deaths  Confirmed
# 77         0          1
# 92         0          1
# 107        0          1
# 118        0          1
# 131        0          1
# ...      ...        ...
# 3521     128       5056
# 3557     133       5216
# 3593     138       5418
# 3629     144       5568
# 3665     149       5668
#
# [116 rows x 7 columns]

# %%
plt.figure(figsize=(10,6))
sns.heatmap(state.corr(),annot=True,linewidth=0.5,linecolor="White")
